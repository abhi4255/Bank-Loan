# %% [markdown]
# # Data Analytics Project

# %% [markdown]
# # Bank Loan

# %% [markdown]
# # Problem Statement:
# - In order to gain a comprehensive overview of our lending operations and
# monitor the performance of loans, we aim to create a grid view report
# categorized by Loan Status.
#
# - By providing insights into metrics such as
#
# o Total Loan Applications
#
# o Total Funded Amount
#
# o Total Amount Received
#
# o Month-to-Date (MTD) Funded Amount
#
# o MTD Amount Received
#
# o Average Interest Rate
#
# o Average Debt-to-Income Ratio (DTI)
# # This Analytics Report will empower us to make data-driven decisions and assess the health of our loan portfolio.

# %% [markdown]
# # Key Performance Indicators (KPIs) Requirements :
#
# # 1. Total Loan Applications :
#
# - We need to calculate the total number of loan applications received during a
# specified period. Additionally, it is essential to monitor the Month-to-Date
# (MTD) Loan Applications and track changes Month-over-Month (MoM).
#
# # 2. Total Funded Amount :
#
# - Understanding the total amount of funds disbursed as loans is crucial. We
# also want to keep an eye on the MTD Total Funded Amount and analyse the
# Month-over-Month (MoM) changes in this metric.
#
# # 3. Total Amount Received :
#
# - Tracking the total amount received from borrowers is essential for assessing the bank's cash flow and loan repayment. We should analyse the Month-to-
# Date (MTD) Total Amount Received and observe the Month-over-Month (MoM) changes.
#
# # 4. Average Interest Rate :
#
# - Calculating the average interest rate across all loans, MTD, and monitoring
# the Month-over-Month (MoM) variations in interest rates will provide
# insights into our lending portfoli overall cost.ations.

# %% [markdown]
# # 5. Average Debt-to-Income Ratio (DTI) :
#
# - Evaluating the average DTI for our borrowers helps us gauge their financial
# health. We need to compute the average DTI for all loans, MTD, and track
# Month-over-Month (MoM) fluctuations.

# %% [markdown]
# # Good Loans:
# 1. Good Loan Application Percentage
# 2. Good Loan Applications
# 3. Good Loan Funded Amount
# 4. Good Loan Total Received Amount
#
# # Bad Loans:
# 5. Bad Loan Application Percentage
# 6. Bad Loan Applications
# 7. Bad Loan Funded Amount
# 8. Bad Loan Total Received Amount
#
# # Chart's Requirement:
#
# # 1. Monthly Trends by Issue Date (Line Chart) :
#
#    To identify seasonality and long-term trends in lending activities
#
# # 3. Regional Analysis by State :
#
#    To identify regions with significant lending activity and assess regional
#    disparities
#
# # 4. Loan Term Analysis :
#
#    To allow the client to understand the distribution of loans across various term
#    lengths.
#
# # 5. Employee Length Analysis :
#
#    How lending metrics are distributed among borrowers with different
#    employment lengths, helping us assess the impact of employment history on
#    loan applications.
#
# # 6. Loan Purpose Breakdown :
#
#    Will provide a visual breakdown of loan metrics based on the stated purposes
#    of loans, aiding in the understanding of the primary reasons borrowers seek
#    financing.
#
# # 7. Home Ownership Analysis :
#
#    For a hierarchical view of how home ownership impacts loan applications and
#    disbursements. DATA

# %% [markdown]
# # Step : 1 Business Problem Understanding  (Analysis)
# 1.id: Unique Loan Id
#
# 2.address_state: The state where the borrower lives
#
# 3.application_type: The type of loan application, such as individual or joint (with co-applicants).
#
# 4.Employment Length: How long the borrower has been employed at their current job (e.g., 10+ years).
#
# 5.emp title: The job title or position of the borrower (e.g. MKC Accounting) employment.
#
# 6.grade: A rating given to the loan based on risk or credit quality, usually assigned by the lender..
#
# 7.home ownership: The borrower's current housing situation, such as owning a home, renting, or living with family.
#
# 8.issue_date: The date when the loan was issued or approved.
#
# 9.last_credit_pull_date: The most recent date when the borrower's credit report was checked. 10.last_payment_date: The date of the borrower's most recent loan payment.
#
# 11.loan_status: The current status of the loan, such as "Fully Paid," "Charged Off," or "In Default."
#
# 12.next payment_date: The date when the borrower's next loan payment is due.
#
# 13.member_id: A unique identifier for the borrower or member in the lending system.
#
# 14. purpose: The reason the loan was taken out, such as for debt consolidation, home improvement, or education. 15.sub grade: A more detailed loan grade, often used to assess risk more precisely than the general grade.
#
# 16. term: The length of time over which the loan will be repaid, typically in months (e.g., 36 months). 17.verification_status: Indicates whether the borrower's income and employment details have been verified.
#
# 18.annual_income: The borrower's total income per year.
#
# 19.dti: The debt-to-income ratio, which shows the borrower's total debt payments compared to their income (a measure financial health).
#
# 20. installment: The amount the borrower pays each month towards the loan.
#
# 21.int rate: The interest rate charged on the loan, usually expressed as a percentage.
#
# 22.loan_amount: The total amount of money borrowed.
#
# 23.total acc: The total number of accounts the borrower has, which can include credit cards, loans, etc. 24.total payment: The total amount paid towards the loan so far.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_excel(r"D:\Datascience\financial_loan.xlsx")
data
# Out:
#             id address_state application_type emp_length  \
# 0      1077430            GA       INDIVIDUAL   < 1 year
# 1      1072053            CA       INDIVIDUAL    9 years
# 2      1069243            CA       INDIVIDUAL    4 years
# 3      1041756            TX       INDIVIDUAL   < 1 year
# 4      1068350            IL       INDIVIDUAL  10+ years
# ...        ...           ...              ...        ...
# 38571   803452            NJ       INDIVIDUAL   < 1 year
# 38572   970377            NY       INDIVIDUAL    8 years
# 38573   875376            CA       INDIVIDUAL    5 years
# 38574   972997            NY       INDIVIDUAL    5 years
# 38575   682952            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership issue_date  \
# 0                                Ryder     C           RENT 2021-02-11
# 1                       MKC Accounting     E           RENT 2021-01-01
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38576 entries, 0 to 38575
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     38576 non-null  int64
#  1   address_state          38576 non-null  object
#  2   application_type       38576 non-null  object
#  3   emp_length             38576 non-null  object
#  4   emp_title              37138 non-null  object
#  5   grade                  38576 non-null  object
#  6   home_ownership         38576 non-null  object
#  7   issue_date             38576 non-null  datetime64[ns]
#  8   last_credit_pull_date  38576 non-null  datetime64[ns]
#  9   last_payment_date      38576 non-null  datetime64[ns]
#  10  loan_status            38576 non-null  object
#  11  next_payment_date      38576 non-null  datetime64[ns]
#  12  member_id              38576 non-null  int64
#  13  purpose                38576 non-null  object
# ...

# %%
data.columns
# Out:
# Index(['id', 'address_state', 'application_type', 'emp_length', 'emp_title',
#        'grade', 'home_ownership', 'issue_date', 'last_credit_pull_date',
#        'last_payment_date', 'loan_status', 'next_payment_date', 'member_id',
#        'purpose', 'sub_grade', 'term', 'verification_status', 'annual_income',
#        'dti', 'installment', 'int_rate', 'loan_amount', 'total_acc',
#        'total_payment'],
#       dtype='object')

# %%
# The nunique() method returns the number of unique values for each column.

data["id"].nunique() 
# There is no use of This column because every record is a diferent.
# So, we should drop this column.
# Out:
# 38576

# %%
# Drop unimportant columns as per feature selection (Filter Methods)

data.drop(columns=["id"],inplace=True) # id was droped.

# %%
data # id was dropped
# Out:
#       address_state application_type emp_length  \
# 0                GA       INDIVIDUAL   < 1 year
# 1                CA       INDIVIDUAL    9 years
# 2                CA       INDIVIDUAL    4 years
# 3                TX       INDIVIDUAL   < 1 year
# 4                IL       INDIVIDUAL  10+ years
# ...             ...              ...        ...
# 38571            NJ       INDIVIDUAL   < 1 year
# 38572            NY       INDIVIDUAL    8 years
# 38573            CA       INDIVIDUAL    5 years
# 38574            NY       INDIVIDUAL    5 years
# 38575            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership issue_date  \
# 0                                Ryder     C           RENT 2021-02-11
# 1                       MKC Accounting     E           RENT 2021-01-01
# 2                Chemat Technology Inc     C           RENT 2021-01-05
# 3                  barnes distribution     B       MORTGAGE 2021-02-25
# ...

# %%
# unique= values that exist only once in the dataset
data["address_state"].unique()
# Out:
# array(['GA', 'CA', 'TX', 'IL', 'PA', 'FL', 'MI', 'RI', 'NY', 'MD', 'WI',
#        'NV', 'UT', 'WA', 'NH', 'HI', 'MA', 'OK', 'NJ', 'OH', 'AZ', 'CT',
#        'MN', 'CO', 'TN', 'VA', 'MO', 'DE', 'NM', 'LA', 'AR', 'KY', 'NC',
#        'SC', 'WV', 'KS', 'WY', 'OR', 'AL', 'VT', 'MS', 'DC', 'MT', 'SD',
#        'AK', 'IN', 'ME', 'ID', 'NE', 'IA'], dtype=object)

# %%
data["address_state"].value_counts()
# Out:
# address_state
# CA    6894
# NY    3701
# FL    2773
# TX    2664
# NJ    1822
# IL    1486
# PA    1482
# VA    1375
# GA    1355
# MA    1310
# OH    1188
# MD    1027
# AZ     833
# WA     805
# CO     770
# NC     759
# CT     730
# MI     685
# MO     660
# MN     592
# NV     482
# SC     464
# WI     446
# OR     436
# AL     432
# LA     426
# KY     320
# OK     293
# KS     260
# UT     252
# AR     236
# DC     214
# RI     196
# NM     183
# HI     170
# WV     167
# NH     161
# DE     110
# WY      79
# MT      79
# AK      78
# SD      63
# VT      54
# MS      19
# TN      17
# IN       9
# ID       6
# NE       5
# IA       5
# ME       3
# Name: count, dtype: int64

# %%
data["application_type"].unique()
# Out:
# array(['INDIVIDUAL'], dtype=object)

# %%
data["application_type"].value_counts()
# Out:
# application_type
# INDIVIDUAL    38576
# Name: count, dtype: int64

# %%
data["emp_length"].unique()
# Out:
# array(['< 1 year', '9 years', '4 years', '10+ years', '3 years',
#        '5 years', '1 year', '6 years', '2 years', '7 years', '8 years'],
#       dtype=object)

# %%
data["emp_length"].value_counts()
# Out:
# emp_length
# 10+ years    8870
# < 1 year     4575
# 2 years      4382
# 3 years      4088
# 4 years      3428
# 5 years      3273
# 1 year       3229
# 6 years      2228
# 7 years      1772
# 8 years      1476
# 9 years      1255
# Name: count, dtype: int64

# %%
data["emp_title"].unique()
# Out:
# array(['Ryder', 'MKC Accounting', 'Chemat Technology Inc', ...,
#        'Anaheim Regional Medical Center', 'Brooklyn Radiology',
#        'Allen Edmonds'], dtype=object)

# %%
data["emp_title"].value_counts()
# Out:
# emp_title
# US Army                           135
# Bank of America                   109
# IBM                                67
# AT&T                               63
# Wells Fargo                        57
#                                  ...
# The Shafer Law Group                1
# U.S navy                            1
# Wellspring Healthcare Services      1
# MacNeill group                      1
# Allen Edmonds                       1
# Name: count, Length: 28522, dtype: int64

# %%
# drop the unimportant values

# Because more then 1000 missing values are there.so, we can drop.

data.dropna(subset=["emp_title"],inplace=True) # null values are drops

# %%
data["grade"].unique()
# Out:
# array(['C', 'E', 'B', 'A', 'D', 'F', 'G'], dtype=object)

# %%
data["grade"].value_counts()
# Out:
# grade
# B    11237
# A     9298
# C     7619
# D     5002
# E     2693
# F      987
# G      302
# Name: count, dtype: int64

# %%
data["home_ownership"].unique()
# Out:
# array(['RENT', 'MORTGAGE', 'OWN', 'OTHER', 'NONE'], dtype=object)

# %%
data["home_ownership"].value_counts()
# Out:
# home_ownership
# RENT        17858
# MORTGAGE    16542
# OWN          2641
# OTHER          96
# NONE            1
# Name: count, dtype: int64

# %%
data["issue_date"].unique()
# Out:
# <DatetimeArray>
# ['2021-02-11 00:00:00', '2021-01-01 00:00:00', '2021-01-05 00:00:00',
#  '2021-02-25 00:00:00', '2021-07-17 00:00:00', '2021-11-19 00:00:00',
#  '2021-06-11 00:00:00', '2021-09-02 00:00:00', '2021-02-09 00:00:00',
#  '2021-07-22 00:00:00', '2021-09-11 00:00:00', '2021-08-11 00:00:00',
#  '2021-12-11 00:00:00', '2021-10-11 00:00:00', '2021-12-02 00:00:00',
#  '2021-10-09 00:00:00', '2021-12-12 00:00:00', '2021-07-07 00:00:00',
#  '2021-08-09 00:00:00', '2021-01-08 00:00:00', '2021-01-11 00:00:00',
#  '2021-11-11 00:00:00', '2021-06-09 00:00:00', '2021-01-10 00:00:00',
#  '2021-03-10 00:00:00', '2021-05-10 00:00:00', '2021-05-09 00:00:00',
#  '2021-04-11 00:00:00', '2021-07-09 00:00:00', '2021-12-09 00:00:00',
#  '2021-11-09 00:00:00', '2021-05-11 00:00:00', '2021-03-09 00:00:00',
#  '2021-10-08 00:00:00', '2021-03-08 00:00:00', '2021-11-08 00:00:00',
#  '2021-09-07 00:00:00', '2021-02-08 00:00:00', '2021-08-07 00:00:00',
# ...

# %%
data["issue_date"].value_counts()
# Out:
# issue_date
# 2021-12-11    2109
# 2021-11-11    2049
# 2021-10-11    1953
# 2021-09-11    1926
# 2021-08-11    1811
#               ...
# 2021-09-02       1
# 2021-07-22       1
# 2021-12-02       1
# 2021-12-12       1
# 2021-06-07       1
# Name: count, Length: 64, dtype: int64

# %%
 data["last_credit_pull_date"].unique()
# Out:
# <DatetimeArray>
# ['2021-09-13 00:00:00', '2021-12-14 00:00:00', '2021-12-12 00:00:00',
#  '2021-03-16 00:00:00', '2021-06-14 00:00:00', '2021-07-14 00:00:00',
#  '2021-06-15 00:00:00', '2021-03-13 00:00:00', '2021-10-13 00:00:00',
#  '2021-02-14 00:00:00',
#  ...
#  '2021-04-09 00:00:00', '2021-10-07 00:00:00', '2021-07-09 00:00:00',
#  '2021-05-08 00:00:00', '2021-03-08 00:00:00', '2021-05-07 00:00:00',
#  '2021-07-08 00:00:00', '2021-09-07 00:00:00', '2021-06-08 00:00:00',
#  '2021-07-07 00:00:00']
# Length: 106, dtype: datetime64[ns]

# %%
 data["last_credit_pull_date"].value_counts()
# Out:
# last_credit_pull_date
# 2021-05-16    9737
# 2021-04-16    2410
# 2021-03-16    1067
# 2021-02-13     775
# 2021-02-16     693
#               ...
# 2021-05-08       1
# 2021-05-07       1
# 2021-07-08       1
# 2021-06-08       1
# 2021-07-07       1
# Name: count, Length: 106, dtype: int64

# %%
data["last_payment_date"].unique()
# Out:
# <DatetimeArray>
# ['2021-04-13 00:00:00', '2021-01-15 00:00:00', '2021-01-09 00:00:00',
#  '2021-03-12 00:00:00', '2021-08-12 00:00:00', '2021-12-13 00:00:00',
#  '2021-07-14 00:00:00', '2021-10-12 00:00:00', '2021-03-16 00:00:00',
#  '2021-08-13 00:00:00',
#  ...
#  '2021-04-09 00:00:00', '2021-05-08 00:00:00', '2021-03-09 00:00:00',
#  '2021-09-08 00:00:00', '2021-11-08 00:00:00', '2021-07-08 00:00:00',
#  '2021-06-08 00:00:00', '2021-03-08 00:00:00', '2021-02-08 00:00:00',
#  '2021-01-08 00:00:00']
# Length: 102, dtype: datetime64[ns]

# %%
data["last_payment_date"].value_counts()
# Out:
# last_payment_date
# 2021-05-16    1173
# 2021-03-13     969
# 2021-12-14     874
# 2021-05-13     857
# 2021-02-13     816
#               ...
# 2021-11-08      10
# 2021-06-08      10
# 2021-03-08       5
# 2021-01-08       2
# 2021-02-08       1
# Name: count, Length: 102, dtype: int64

# %%
data["loan_status"].unique()
# Out:
# array(['Charged Off', 'Fully Paid', 'Current'], dtype=object)

# %%
data["loan_status"].value_counts()
# Out:
# loan_status
# Fully Paid     31005
# Charged Off     5067
# Current         1066
# Name: count, dtype: int64

# %%
data["next_payment_date"].unique()
# Out:
# <DatetimeArray>
# ['2021-05-13 00:00:00', '2021-02-15 00:00:00', '2021-02-09 00:00:00',
#  '2021-04-12 00:00:00', '2021-09-12 00:00:00', '2022-01-13 00:00:00',
#  '2021-08-14 00:00:00', '2021-11-12 00:00:00', '2021-04-16 00:00:00',
#  '2021-09-13 00:00:00',
#  ...
#  '2021-05-09 00:00:00', '2021-06-08 00:00:00', '2021-04-09 00:00:00',
#  '2021-10-08 00:00:00', '2021-12-08 00:00:00', '2021-08-08 00:00:00',
#  '2021-07-08 00:00:00', '2021-04-08 00:00:00', '2021-03-08 00:00:00',
#  '2021-02-08 00:00:00']
# Length: 102, dtype: datetime64[ns]

# %%
data["next_payment_date"].value_counts()
# Out:
# next_payment_date
# 2021-06-16    1173
# 2021-04-13     969
# 2022-01-14     874
# 2021-06-13     857
# 2021-03-13     816
#               ...
# 2021-12-08      10
# 2021-07-08      10
# 2021-04-08       5
# 2021-02-08       2
# 2021-03-08       1
# Name: count, Length: 102, dtype: int64

# %%
data["member_id"].nunique() 
# There is no use of This column because every record is a diferent.
# So, we should drop this column.
# Out:
# 37138

# %%
# Drop unimportant columns as per feature selection (Filter Methods)

data.drop(columns=["member_id"],inplace=True) # id was droped.

# %%
data
# Out:
#       address_state application_type emp_length  \
# 0                GA       INDIVIDUAL   < 1 year
# 1                CA       INDIVIDUAL    9 years
# 2                CA       INDIVIDUAL    4 years
# 3                TX       INDIVIDUAL   < 1 year
# 4                IL       INDIVIDUAL  10+ years
# ...             ...              ...        ...
# 38571            NJ       INDIVIDUAL   < 1 year
# 38572            NY       INDIVIDUAL    8 years
# 38573            CA       INDIVIDUAL    5 years
# 38574            NY       INDIVIDUAL    5 years
# 38575            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership issue_date  \
# 0                                Ryder     C           RENT 2021-02-11
# 1                       MKC Accounting     E           RENT 2021-01-01
# 2                Chemat Technology Inc     C           RENT 2021-01-05
# 3                  barnes distribution     B       MORTGAGE 2021-02-25
# ...

# %%
data["purpose"].unique()
# Out:
# array(['car', 'credit card', 'Debt consolidation', 'educational',
#        'home improvement', 'house', 'major purchase', 'medical', 'moving',
#        'other', 'renewable_energy', 'small business', 'vacation',
#        'wedding'], dtype=object)

# %%
data["purpose"].value_counts()
# Out:
# purpose
# Debt consolidation    17762
# credit card            4820
# other                  3682
# home improvement       2754
# major purchase         2033
# small business         1462
# car                    1461
# wedding                 905
# medical                 644
# moving                  540
# house                   348
# vacation                342
# educational             297
# renewable_energy         88
# Name: count, dtype: int64

# %%
data["sub_grade"].unique()
# Out:
# array(['C4', 'E1', 'C5', 'B2', 'A1', 'C3', 'C2', 'A4', 'A5', 'B5', 'B4',
#        'B3', 'B1', 'A2', 'A3', 'D4', 'D2', 'C1', 'D3', 'D1', 'E3', 'F1',
#        'E2', 'E5', 'D5', 'E4', 'F2', 'G3', 'F3', 'G1', 'F4', 'G4', 'G2',
#        'F5', 'G5'], dtype=object)

# %%
data["sub_grade"].value_counts()
# Out:
# sub_grade
# B3    2710
# A4    2698
# B5    2569
# A5    2538
# B4    2360
# C1    2000
# B2    1914
# C2    1907
# B1    1684
# A3    1667
# C3    1442
# A2    1381
# D2    1272
# C4    1158
# C5    1112
# D3    1103
# A1    1014
# D4     929
# D1     879
# D5     819
# E1     737
# E2     615
# E3     523
# E4     432
# E5     386
# F1     318
# F2     236
# F3     173
# F4     155
# F5     105
# G1     100
# G2      76
# G4      56
# G3      44
# G5      26
# Name: count, dtype: int64

# %%
data["term"].unique()
# Out:
# array(['60 months', '36 months'], dtype=object)

# %%
data["term"].value_counts()
# Out:
# term
# 36 months    27077
# 60 months    10061
# Name: count, dtype: int64

# %%
data["verification_status"].unique()
# Out:
# array(['Source Verified', 'Not Verified', 'Verified'], dtype=object)

# %%
data["verification_status"].value_counts()
# Out:
# verification_status
# Not Verified       15737
# Verified           11936
# Source Verified     9465
# Name: count, dtype: int64

# %%
data["annual_income"].unique()
# Out:
# array([ 30000. ,  48000. ,  50000. , ...,  44250. ,  57040.5, 368000. ])

# %%
data["annual_income"].value_counts()
# Out:
# annual_income
# 60000.0     1391
# 50000.0      973
# 40000.0      815
# 45000.0      783
# 65000.0      772
#             ...
# 98080.0        1
# 33168.0        1
# 59147.0        1
# 97296.0        1
# 368000.0       1
# Name: count, Length: 4992, dtype: int64

# %%
data["dti"].unique()
# Out:
# array([0.01  , 0.0535, 0.2088, ..., 0.2721, 0.2543, 0.272 ])

# %%
data["dti"].value_counts()
# Out:
# dti
# 0.0000    167
# 0.1200     45
# 0.1800     42
# 0.1920     38
# 0.1248     37
#          ...
# 0.2960      1
# 0.2961      1
# 0.2670      1
# 0.2826      1
# 0.2720      1
# Name: count, Length: 2857, dtype: int64

# %%
data["installment"].unique()
# Out:
# array([ 59.83, 109.43, 421.65, ..., 164.99, 113.5 , 627.93])

# %%
data["installment"].value_counts()
# Out:
# installment
# 311.11    65
# 311.02    53
# 180.96    52
# 150.80    43
# 368.45    43
#           ..
# 297.03     1
# 265.97     1
# 413.14     1
# 978.46     1
# 627.93     1
# Name: count, Length: 14770, dtype: int64

# %%
data["int_rate"].unique()
# Out:
# array([0.1527, 0.1864, 0.1596, 0.1065, 0.0603, 0.1465, 0.1427, 0.079 ,
#        0.089 , 0.1269, 0.1242, 0.1171, 0.0991, 0.0743, 0.1114, 0.1109,
#        0.0766, 0.0751, 0.0963, 0.0894, 0.1148, 0.157 , 0.0788, 0.0705,
#        0.1189, 0.1074, 0.1284, 0.0749, 0.0849, 0.1136, 0.1199, 0.1095,
#        0.1099, 0.1221, 0.1241, 0.1134, 0.1399, 0.1367, 0.1677, 0.1   ,
#        0.0807, 0.0863, 0.0976, 0.1393, 0.0712, 0.1046, 0.092 , 0.1166,
#        0.1091, 0.1103, 0.074 , 0.0768, 0.0662, 0.0599, 0.0699, 0.0729,
#        0.0542, 0.0676, 0.0774, 0.0692, 0.0932, 0.0617, 0.0639, 0.0579,
#        0.08  , 0.0859, 0.0714, 0.0691, 0.0737, 0.0832, 0.0925, 0.1075,
#        0.0999, 0.1036, 0.1025, 0.1149, 0.1111, 0.1126, 0.1218, 0.1059,
#        0.0962, 0.1037, 0.1158, 0.0988, 0.1062, 0.1253, 0.1051, 0.1287,
#        0.1273, 0.138 , 0.1472, 0.1347, 0.1523, 0.1426, 0.1268, 0.1311,
#        0.1417, 0.1349, 0.1304, 0.1599, 0.1595, 0.1533, 0.0654, 0.1183,
# ...

# %%
data["int_rate"].value_counts()
# Out:
# int_rate
# 0.1099    901
# 0.1349    785
# 0.1149    768
# 0.0751    731
# 0.0788    674
#          ...
# 0.1696      1
# 0.1872      1
# 0.1601      1
# 0.1467      1
# 0.1754      1
# Name: count, Length: 368, dtype: int64

# %%
data["loan_amount"].unique()
# Out:
# array([ 2500,  3000, 12000,  4500,  3500,  8000,  6000,  5500, 24000,
#         4125,  5400, 11200,  5000,  3050, 10000,  4000,  7000,  9000,
#         4800,  6300,  4750,  1850,  4200,  7200,  2400,  7500,  5550,
#        22000,  3200, 11000,  4400,  8500,  2000,  7400,  5650,  1800,
#         6500, 15000,  8700,  5600,  4600,  3800, 16000,  1300,  7800,
#         5900,  3600,  2100,  4975,  1925,  1500,  7750,  9600,  3900,
#        12975,  5950,  5100,  5200,  1200,  4650,  1450,  3250,  1700,
#         5525, 18000,  1750,  5375,  9500,  7600,  6400,  9900,  1000,
#        10400, 13100,  5800, 10800,  1900,  3075,  6200, 11500,  4350,
#         4150,  4900,  6125,  2425,  1600,  7100,  8900, 14000, 12250,
#         3700,  3300,  8400, 17000,  2550,  8200,  9250,  3375,  1675,
#         8600,  2800,  3525,  8800,  2250,  4375,  1275,  5050, 25000,
#         9800,  6600, 14400,  8250,  2825,  5975,  3350, 20000, 19000,
# ...

# %%
data["loan_amount"].value_counts()
# Out:
# loan_amount
# 10000    2680
# 12000    2231
# 5000     1885
# 6000     1793
# 15000    1792
#          ...
# 13025       1
# 23475       1
# 800         1
# 11475       1
# 24975       1
# Name: count, Length: 874, dtype: int64

# %%
data["total_acc"].unique()
# Out:
# array([ 4, 11,  9, 28, 30, 23, 31, 21, 33, 13,  3, 15, 18, 14,  8,  7, 39,
#        24, 10, 19,  6, 16, 45, 25,  5, 43, 29, 22, 41, 27, 35, 44, 36, 17,
#        26, 37, 32, 47, 52, 42, 20, 46, 12, 50, 34, 59, 38, 63, 49, 48, 61,
#        51, 55, 40, 53, 62, 58, 67, 54, 57, 56, 70,  2, 64, 60, 80, 79, 71,
#        66, 69, 65, 90, 68, 75, 87, 78, 72, 81, 76, 73], dtype=int64)

# %%
data["total_acc"].value_counts()
# Out:
# total_acc
# 17    1366
# 15    1362
# 16    1361
# 14    1357
# 20    1350
#       ...
# 78       1
# 72       1
# 81       1
# 76       1
# 73       1
# Name: count, Length: 80, dtype: int64

# %%
data["total_payment"].unique()
# Out:
# array([ 1009,  3939,  3522, ..., 31870, 35721, 33677], dtype=int64)

# %%
data["total_payment"].value_counts()
# Out:
# total_payment
# 6515     31
# 11200    29
# 11197    26
# 6720     25
# 11164    22
#          ..
# 3096      1
# 17158     1
# 36307     1
# 18000     1
# 33677     1
# Name: count, Length: 19143, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37138 entries, 0 to 38575
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   address_state          37138 non-null  object
#  1   application_type       37138 non-null  object
#  2   emp_length             37138 non-null  object
#  3   emp_title              37138 non-null  object
#  4   grade                  37138 non-null  object
#  5   home_ownership         37138 non-null  object
#  6   issue_date             37138 non-null  datetime64[ns]
#  7   last_credit_pull_date  37138 non-null  datetime64[ns]
#  8   last_payment_date      37138 non-null  datetime64[ns]
#  9   loan_status            37138 non-null  object
#  10  next_payment_date      37138 non-null  datetime64[ns]
#  11  purpose                37138 non-null  object
#  12  sub_grade              37138 non-null  object
#  13  term                   37138 non-null  object
# ...

# %%
data
# Out:
#       address_state application_type emp_length  \
# 0                GA       INDIVIDUAL   < 1 year
# 1                CA       INDIVIDUAL    9 years
# 2                CA       INDIVIDUAL    4 years
# 3                TX       INDIVIDUAL   < 1 year
# 4                IL       INDIVIDUAL  10+ years
# ...             ...              ...        ...
# 38571            NJ       INDIVIDUAL   < 1 year
# 38572            NY       INDIVIDUAL    8 years
# 38573            CA       INDIVIDUAL    5 years
# 38574            NY       INDIVIDUAL    5 years
# 38575            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership issue_date  \
# 0                                Ryder     C           RENT 2021-02-11
# 1                       MKC Accounting     E           RENT 2021-01-01
# 2                Chemat Technology Inc     C           RENT 2021-01-05
# 3                  barnes distribution     B       MORTGAGE 2021-02-25
# ...

# %%
data.isnull().sum()
# Out:
# address_state            0
# application_type         0
# emp_length               0
# emp_title                0
# grade                    0
# home_ownership           0
# issue_date               0
# last_credit_pull_date    0
# last_payment_date        0
# loan_status              0
# next_payment_date        0
# purpose                  0
# sub_grade                0
# term                     0
# verification_status      0
# annual_income            0
# dti                      0
# installment              0
# int_rate                 0
# loan_amount              0
# total_acc                0
# total_payment            0
# dtype: int64

# %%
data
# Out:
#       address_state application_type emp_length  \
# 0                GA       INDIVIDUAL   < 1 year
# 1                CA       INDIVIDUAL    9 years
# 2                CA       INDIVIDUAL    4 years
# 3                TX       INDIVIDUAL   < 1 year
# 4                IL       INDIVIDUAL  10+ years
# ...             ...              ...        ...
# 38571            NJ       INDIVIDUAL   < 1 year
# 38572            NY       INDIVIDUAL    8 years
# 38573            CA       INDIVIDUAL    5 years
# 38574            NY       INDIVIDUAL    5 years
# 38575            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership issue_date  \
# 0                                Ryder     C           RENT 2021-02-11
# 1                       MKC Accounting     E           RENT 2021-01-01
# 2                Chemat Technology Inc     C           RENT 2021-01-05
# 3                  barnes distribution     B       MORTGAGE 2021-02-25
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37138 entries, 0 to 38575
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   address_state          37138 non-null  object
#  1   application_type       37138 non-null  object
#  2   emp_length             37138 non-null  object
#  3   emp_title              37138 non-null  object
#  4   grade                  37138 non-null  object
#  5   home_ownership         37138 non-null  object
#  6   issue_date             37138 non-null  datetime64[ns]
#  7   last_credit_pull_date  37138 non-null  datetime64[ns]
#  8   last_payment_date      37138 non-null  datetime64[ns]
#  9   loan_status            37138 non-null  object
#  10  next_payment_date      37138 non-null  datetime64[ns]
#  11  purpose                37138 non-null  object
#  12  sub_grade              37138 non-null  object
#  13  term                   37138 non-null  object
# ...

# %%
continous=["issue_date","last_credit_pull_date","last_payment_date","next_payment_date","annual_income","dti","int_rate","loan_amount","total_acc","total_payment"]

discrete_categorical = ["application_type","purpose","home_ownership","loan_status"]

discrete_count = ["emp_length","address_state","grade","sub_grade","term","verification_status","installment"]

# %%
data.dtypes
# Out:
# address_state                    object
# application_type                 object
# emp_length                       object
# emp_title                        object
# grade                            object
# home_ownership                   object
# issue_date               datetime64[ns]
# last_credit_pull_date    datetime64[ns]
# last_payment_date        datetime64[ns]
# loan_status                      object
# next_payment_date        datetime64[ns]
# purpose                          object
# sub_grade                        object
# term                             object
# verification_status              object
# annual_income                   float64
# dti                             float64
# installment                     float64
# int_rate                        float64
# loan_amount                       int64
# total_acc                         int64
# total_payment                     int64
# dtype: object

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# # For Continous Variables

# %%
data
# Out:
#       address_state application_type emp_length  \
# 0                GA       INDIVIDUAL   < 1 year
# 1                CA       INDIVIDUAL    9 years
# 2                CA       INDIVIDUAL    4 years
# 3                TX       INDIVIDUAL   < 1 year
# 4                IL       INDIVIDUAL  10+ years
# ...             ...              ...        ...
# 38571            NJ       INDIVIDUAL   < 1 year
# 38572            NY       INDIVIDUAL    8 years
# 38573            CA       INDIVIDUAL    5 years
# 38574            NY       INDIVIDUAL    5 years
# 38575            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership issue_date  \
# 0                                Ryder     C           RENT 2021-02-11
# 1                       MKC Accounting     E           RENT 2021-01-01
# 2                Chemat Technology Inc     C           RENT 2021-01-05
# 3                  barnes distribution     B       MORTGAGE 2021-02-25
# ...

# %%
data[continous].describe()
# describe function apply only on the continous variable.
# Out:
#                           issue_date          last_credit_pull_date  \
# count                          37138                          37138
# mean   2021-07-15 23:24:28.964402944  2021-06-08 12:26:21.991491072
# min              2021-01-01 00:00:00            2021-01-08 00:00:00
# 25%              2021-04-11 00:00:00            2021-04-15 00:00:00
# 50%              2021-07-11 00:00:00            2021-05-16 00:00:00
# 75%              2021-10-11 00:00:00            2021-08-13 00:00:00
# max              2021-12-12 00:00:00            2021-12-15 00:00:00
# std                              NaN                            NaN
#
#                    last_payment_date              next_payment_date  \
# count                          37138                          37138
# mean   2021-06-26 11:39:54.894716928  2021-07-26 22:32:54.775162624
# min              2021-01-08 00:00:00            2021-02-08 00:00:00
# 25%              2021-03-16 00:00:00            2021-04-16 00:00:00
# ...

# %%
# check the histogram.
					
# for each continous variable we chek the histogram.

plt.rcParams["figure.figsize"]=(30,20)

# check for Income.
plt.subplot(2,5,1) # (row,columns,place)
sns.histplot(data["issue_date"],kde=True)

# check for last_credit_pull_date.
plt.subplot(2,5,2) # (row,columns,place)
sns.histplot(data["last_credit_pull_date"],kde=True)

# check for last_payment_date.
plt.subplot(2,5,3) # (row,columns,place)
sns.histplot(data["last_payment_date"],kde=True)

# check for next_payment_date.
plt.subplot(2,5,4) # (row,columns,place)
sns.histplot(data["next_payment_date"],kde=True)

# check for annual_income.
plt.subplot(2,5,5) # (row,columns,place)
sns.histplot(data["annual_income"],kde=True)

# check for dti.
plt.subplot(2,5,6) # (row,columns,place)
sns.histplot(data["dti"],kde=True)

# check for int_rate.
plt.subplot(2,5,7) # (row,columns,place)
sns.histplot(data["int_rate"],kde=True)

# check for loan_amount.
plt.subplot(2,5,8) # (row,columns,place)
sns.histplot(data["loan_amount"],kde=True)

# check for total_acc.
plt.subplot(2,5,9) # (row,columns,place)
sns.histplot(data["total_acc"],kde=True)

# check for total_payment.
plt.subplot(2,5,10) # (row,columns,place)
sns.histplot(data["total_payment"],kde=True)


# Subtitle for the plots
plt.suptitle("Univarite Analysis on Numerical Columns")
plt.show()

# %%
# check the correlation matrix apply only for continous variable.

# for that here we applying the heatmap.

sns.heatmap(data[continous].corr(),annot=True) # annot means label the values in the box.
plt.show()

# %%
# for continous how many plots are there all we should be applyed.

sns.pairplot(data[continous])
plt.show()

# %% [markdown]
# # For Discrete variables

# %%
data[discrete_categorical].describe()
# Out:
#        application_type             purpose home_ownership loan_status
# count             37138               37138          37138       37138
# unique                1                  14              5           3
# top          INDIVIDUAL  Debt consolidation           RENT  Fully Paid
# freq              37138               17762          17858       31005

# %%
plt.rcParams["figure.figsize"]=(20,10)

plt.subplot(2,2,1)           # (rows , columns , place)
sns.countplot(data["application_type"])

plt.subplot(2,2,2)           # (rows, columns, place)
sns.countplot(data["purpose"])

plt.subplot(2,2,3)           # (rows,columns,place)
sns.countplot(data["home_ownership"])

plt.subplot(2,2,4)           # (rows,columns,place)
sns.countplot(data["loan_status"])
# Out:
# <Axes: xlabel='count', ylabel='loan_status'>

# %% [markdown]
# # Check for Missing Values

# %%
data.isnull().sum()
# Out:
# address_state            0
# application_type         0
# emp_length               0
# emp_title                0
# grade                    0
# home_ownership           0
# issue_date               0
# last_credit_pull_date    0
# last_payment_date        0
# loan_status              0
# next_payment_date        0
# purpose                  0
# sub_grade                0
# term                     0
# verification_status      0
# annual_income            0
# dti                      0
# installment              0
# int_rate                 0
# loan_amount              0
# total_acc                0
# total_payment            0
# dtype: int64

# %%
data.isnull().sum()/len(data)*100
# Here i'am having everything is lessthen 10% only so, no need to drop any columan based on the missing values
# Out:
# address_state            0.0
# application_type         0.0
# emp_length               0.0
# emp_title                0.0
# grade                    0.0
# home_ownership           0.0
# issue_date               0.0
# last_credit_pull_date    0.0
# last_payment_date        0.0
# loan_status              0.0
# next_payment_date        0.0
# purpose                  0.0
# sub_grade                0.0
# term                     0.0
# verification_status      0.0
# annual_income            0.0
# dti                      0.0
# installment              0.0
# int_rate                 0.0
# loan_amount              0.0
# total_acc                0.0
# total_payment            0.0
# dtype: float64

# %% [markdown]
# # Check Outliers

# %%
# Lets visualize the outliers using box plot

# check for Income.
plt.subplot(2,5,1) # (row,columns,place)
sns.boxplot(data["issue_date"])

# check for last_credit_pull_date.
plt.subplot(2,5,2) # (row,columns,place)
sns.boxplot(data["last_credit_pull_date"])

# check for last_payment_date.
plt.subplot(2,5,3) # (row,columns,place)
sns.boxplot(data["last_payment_date"])

# check for next_payment_date.
plt.subplot(2,5,4) # (row,columns,place)
sns.boxplot(data["next_payment_date"])

# check for annual_income.
plt.subplot(2,5,5) # (row,columns,place)
sns.boxplot(data["annual_income"])

# check for dti.
plt.subplot(2,5,6) # (row,columns,place)
sns.boxplot(data["dti"])

# check for int_rate.
plt.subplot(2,5,7) # (row,columns,place)
sns.boxplot(data["int_rate"])

# check for loan_amount.
plt.subplot(2,5,8) # (row,columns,place)
sns.boxplot(data["loan_amount"])

# check for total_acc.
plt.subplot(2,5,9) # (row,columns,place)
sns.boxplot(data["total_acc"])

# check for total_payment.
plt.subplot(2,5,10) # (row,columns,place)
sns.boxplot(data["total_payment"])

plt.suptitle("Outliers in the Data")
plt.show()

# %% [markdown]
# . if Outliers are there we have the 3 options
#
# . Remove
#
# . Replace
#
# . Retrain

# %%
data.isnull().sum()
# Out:
# address_state            0
# application_type         0
# emp_length               0
# emp_title                0
# grade                    0
# home_ownership           0
# issue_date               0
# last_credit_pull_date    0
# last_payment_date        0
# loan_status              0
# next_payment_date        0
# purpose                  0
# sub_grade                0
# term                     0
# verification_status      0
# annual_income            0
# dti                      0
# installment              0
# int_rate                 0
# loan_amount              0
# total_acc                0
# total_payment            0
# dtype: int64

# %%
data.to_excel("cleaned.xlsx")

# %%
pwd
# Out:
# 'C:\\Users\\abhis'
